# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
partial_corr_long = pd.read_csv("partial_correlation_long.tsv", sep='\t')
partial_corr_long['partial_correlation'].abs().hist(bins=100)
plt.show()

# %%
partial_corr_long['partial_correlation'].max()
# Out:
# 0.5199305855354336

# %%
partial_corr_long['partial_correlation'].min()
# Out:
# -0.1577003135248185
